# %%
import os 
from huggingface_hub import snapshot_download

HF_DIR = '/mnt/storage/nickmcarthy/ct-rate/huggingface/'

# From Med3DVLM README.md 
DCFormer_URL = 'https://huggingface.co/MagicXin/DCFormer_SigLIP'
QWEN_URL = 'https://huggingface.co/MagicXin/Med3DVLM-Qwen-2.5-7B'

repo_names = ['MagicXin/DCFormer_SigLIP', 
              'MagicXin/Med3DVLM-Qwen-2.5-7B']
          
for repo in repo_names:
    local_dir = os.path.join(HF_DIR, os.path.basename(repo))
    snapshot_download('MagicXin/DCFormer_SigLIP', local_dir=local_dir, local_dir_use_symlinks=False)

# %%
snapshot_download(repo_id="bert-base-uncased", local_dir=HF_DIR)
# Out:
# Fetching 16 files:   0%|          | 0/16 [00:00<?, ?it/s]
# model.mlmodel:   0%|          | 0.00/165k [00:00<?, ?B/s]
# .gitattributes:   0%|          | 0.00/491 [00:00<?, ?B/s]
# LICENSE:   0%|          | 0.00/11.4k [00:00<?, ?B/s]
# (…)583cd59cda63c2f1b6e95a03970d772bf097e289:   0%|          | 0.00/532M [00:00<?, ?B/s]
# flax_model.msgpack:   0%|          | 0.00/438M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Manifest.json:   0%|          | 0.00/617 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# (…)aea3a590e6af0ce33e25481136f7eeecb62e5f7f:   0%|          | 0.00/532M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/440M [00:00<?, ?B/s]
# (…)0d041f9b76729bf475d6c017a0e9304a38f89972:   0%|          | 0.00/534M [00:00<?, ?B/s]
# (…)42cad6d24496db3850a2a43d8258221018ce87d2:   0%|          | 0.00/536M [00:00<?, ?B/s]
# ...
